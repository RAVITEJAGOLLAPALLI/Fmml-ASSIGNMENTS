# %% [markdown]
# <a href="https://colab.research.google.com/github/RAVITEJAGOLLAPALLI/Fmml-ASSIGNMENTS/blob/main/MODULE_8%20Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-06-15 16:47:57--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   199MB/s    in 0.3s
#
# 2023-06-15 16:48:00 (199 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 39700  1702.05156v1  Motion detection in video is important for a n...    cs
# 13445   1306.3018v1  An artificial Ant Colony System (ACS) algorith...    cs
# 21856   1401.5625v1  The notion of causality is used in many situat...  stat
# 267    1501.04346v1  While computer and communication technologies ...  stat
# 9891    1405.1513v1  In this paper, a mathematical theory of learni...    cs
# ...             ...                                                ...   ...
# 31427  1803.03577v1  Avoiding collisions with vulnerable road users...    cs
# 35415  cs/0603080v1  The unification algorithm is at the core of th...    cs
# 29255  1708.08998v1  Inverse rendering in a 3D format denoted to re...    cs
# 20408  1512.06747v1  Accurate and computationally efficient means f...    cs
# 11121   1409.1458v2  Communication remains the most significant bot...    cs
#
#                                                    title  year  \
# 39700  An Analysis of Parallelized Motion Masking Usi...  2017
# 13445                    Second Order Swarm Intelligence  2013
# 21856  Identifiability of an Integer Modular Acyclic ...  2014
# 267    Mathematical Language Processing: Automatic Gr...  2015
# 9891                   A Mathematical Theory of Learning  2014
# ...                                                  ...   ...
# 31427  Intentions of Vulnerable Road Users - Detectio...  2018
# 35415        Yet Another Efficient Unification Algorithm  2006
# 29255    Deep Structure for end-to-end inverse rendering  2017
# 20408  Multivariate Time Series Classification Using ...  2015
# 11121  Communication-Efficient Distributed Dual Coord...  2014
#
#                                                 keywords
# 39700  [detection, important, applications, surveilla...
# 13445  [artificial, algorithm, combinatorial, optimiz...
# 21856  [causality, situations, uncertainty, causality...
# 267    [communication, technologies, effective, educa...
# 9891   [mathematical, parallels, information, selecti...
# ...                                                  ...
# 31427  [collisions, vulnerable, recognition, situatio...
# 35415  [unification, algorithm, programming, unificat...
# 29255  [rendering, recovering, properties, typically,...
# 20408  [computationally, efficient, classifying, acti...
# 11121  [communication, significant, bottleneck, perfo...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 39700    [detection, important, applications, surveilla...
# 13445    [artificial, algorithm, combinatorial, optimiz...
# 21856    [causality, situations, uncertainty, causality...
# 267      [communication, technologies, effective, educa...
# 9891     [mathematical, parallels, information, selecti...
#                                ...
# 13621    [algorithms, considered, efficient, techniques...
# 24613    [optimality, eigenfunctions, representing, fun...
# 40179    [optimization, estimation, measurements, forma...
# 26769    [deblurring, approaches, advantage, informatio...
# 7740     [potential, correlated, association, overfitti...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8727 words.
# Out of those 4603 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="543cad36-570c-4d8c-9fdb-7d45ceca2ccd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("543cad36-570c-4d8c-9fdb-7d45ceca2ccd")) {                    Plotly.newPlot(                        "543cad36-570c-4d8c-9fdb-7d45ceca2ccd",                        [{"x":["implement","libraries","parallelization","subtraction","detecting","essential","segmentation","improvements","particularly","implementation","attempting","characteristics","techniques","compensate","surveillance","necessary","reference","recognition","successful","theoretical","applications","attributes","selection","detection","parallelized","available","important","technique","foreground","background","differencing","implemented","algorithm","artificial","favourably","pheromone","compromise","combinatorial","feedbacks","reallocate","accordingly","intelligence","symmetrical","optimization","benchmarks","described","biological","inclusion","benchmark","different","variables","particular","demonstrate","situations","discovery","identifiability","structure","condition","sufficient","multivariate","identified","performance","comparisons","bivariate","causality","conventional","continuous","uncertainty","practical","generated","framework","educational","platforms","assessments","automatically","education","technology","comprises","leverages","prominently","remaining","assignment","submission","determine","algorithms","questions","assignments","automatic","substantially","communication","partially","solutions","correctness","nonparametrics","technologies","structures","numerical","mathematical","effective","inspiration","incorrect","locations","processing","engineering","clustering","approaches","instructor","satisfies","selecting","theoretic","centroids","classical","approximately","information","depending","inequality","sensitive","algorithmic","parametrized","classification","stability","analogous","generalization","immediately","parallels","functions","empirical","inequalities","consequently","equivalently","hypothesis","difference","concentration","properties","interesting","association","perturbation","quantifies","treatment","challenge","operators","constructs","combination","opportunities","preferences","computation","determines","combinations","parameter","architecture","disadvantages","diversity","multitude","reinforcement","difficult","constitute","mechanism","parameters","especially","formulation","coefficients","measurement","comparable","previously","introduce","therefore","regularizer","compressed","literature","correlated","regression","belonging","exhibiting","introduced","subsequent","efficiency","investigate","instances","effectiveness","considerably","execution","worthwhile","additional","practicability","desirable","simplification","infeasible","maximizing","criterion","behaviour","metalevel","improvement","incremental","essentially","stochastic","heuristic","outperform","formalize","establishes","variations"],"y":[58,4,10,6,74,66,198,134,76,129,7,91,350,9,30,95,59,348,71,146,415,57,141,323,7,325,349,244,16,81,2,98,811,158,5,3,6,46,6,2,23,108,3,309,93,72,45,14,241,786,153,259,525,46,50,3,330,51,69,29,45,886,25,2,8,92,121,75,112,183,565,5,32,14,182,7,49,22,29,2,21,27,2,70,597,64,11,176,35,68,49,143,6,1,37,133,83,70,236,8,12,40,307,67,149,435,1,21,38,31,5,100,36,679,33,4,66,41,7,491,38,11,111,10,4,213,143,6,31,5,54,62,3,208,62,25,10,3,29,169,53,21,140,14,34,167,13,37,119,239,11,42,5,125,134,12,115,260,114,76,35,34,89,96,347,133,19,25,130,29,109,11,10,119,29,146,125,110,193,27,35,3,100,2,27,8,14,30,51,30,2,119,33,25,132,57,103,20,12,64],"type":"bar"},{"x":["implement","libraries","parallelization","subtraction","detecting","essential","segmentation","improvements","part ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4603,), (4603, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8233333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Class</span> <span style=''>of</span> <span style=''>Parallel</span> <span style=''>Doubly</span> <span style='background-color:rgba(255, 0, 0, 0.3299492385786802);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>Large</span> <span style=''>Scale</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>over</span> <span style=''>training</span> <span style=''>sets</span> <span style=''>in</span> <span style=''>which</span> <span style=''>both</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>training</span> <span style=''>examples</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4848484848484848);'>dimension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>feature</span> <span style=''>vectors</span> <span style=''>are</span> <span style=''>large</span> <span style=''>To</span> <span style=''>solve</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>the</span> <span style=''>random</span> <span style=''>parallel</span> <span style='background-color:rgba(255, 0, 0, 0.3299492385786802);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>(RAPSA)</span> <span style=''>We</span> <span style=''>call</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>random</span> <span style=''>parallel</span> <span style=''>because</span> <span style=''>it</span> <span style=''>utilizes</span> <span style=''>multiple</span> <span style=''>parallel</span> <span style='background-color:rgba(0, 255, 0, 0.4999999999999999);'>processors</span> <span style=''>to</span> <span style=''>operate</span> <span style=''>on</span> <span style=''>a</span> <span style=''>randomly</span> <span style=''>chosen</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>blocks</span> <span style=''>of</span> <span style=''>the</span> <span style=''>feature</span> <span style=''>vector</span> <span style=''>We</span> <span style=''>call</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.3299492385786802);'>stochastic</span> <span style=''>because</span> <span style='background-color:rgba(0, 255, 0, 0.4999999999999999);'>processors</span> <span style=''>choose</span> <span style=''>training</span> <span style=''>subsets</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uniformly</span> <span style=''>at</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>that</span> <span style=''>are</span> <span style=''>parallel</span> <span style=''>in</span> <span style=''>either</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensions</span> <span style=''>exist</span> <span style=''>but</span> <span style=''>RAPSA</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style=''>attempt</span> <span style=''>at</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>that</span> <span style=''>is</span> <span style=''>parallel</span> <span style=''>in</span> <span style=''>both</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>of</span> <span style=''>blocks</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Extracting</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>dynamics</span> <span style=''>from</span> <span style=''>multiple</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>neural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recordings</span> <span style=''>by</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>predict</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <br/><br/><span style=''>A</span> <span style=''>powerful</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>neural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style=''>dynamics</span> <span style=''>is</span> <span style=''>to</span> <span style=''>extract</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>trajectories</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recordings</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>methods</span> <span style=''>Current</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>on</span> <span style=''>neural</span> <span style=''>data</span> <span style=''>are</span> <span style=''>limited</span> <span style=''>to</span> <span style=''>single</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recordings</span> <span style=''>and</span> <span style=''>can</span> <span style=''>not</span> <span style=''>identify</span> <span style=''>dynamics</span> <span style=''>embedded</span> <span style=''>across</span> <span style=''>multiple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extracting</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>dynamics</span> <span style=''>from</span> <span style=''>multiple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recordings</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>scales</span> <span style=''>to</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comprising</span> <span style=''>millions</span> <span style=''>of</span> <span style=''>observed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>making</span> <span style=''>it</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>access</span> <span style=''>dynamics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>across</span> <span style=''>large</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>populations</span> <span style=''>or</span> <span style=''>multiple</span> <span style=''>brain</span> <span style=''>areas</span> <span style=''>Building</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Compact</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3106382978723405);'>Regularization</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>impact</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3106382978723405);'>regularization</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>Our</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>speeding</span> <span style=''>up</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3480662983425414);'>improving</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>and</span> <span style=''>training</span> <span style=''>compact</span> <span style=''>models</span> <span style=''>that</span> <span style=''>are</span> <span style=''>cost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>apply</span> <span style=''>to</span> <span style=''>weight</span> <span style=''>sharing</span> <span style=''>(egconvolutional)</span> <span style=''>sparsity</span> <span style=''>(iepruning)</span> <span style=''>and</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>among</span> <span style=''>others</span> <span style=''>We</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>covering</span> <span style='background-color:rgba(255, 0, 0, 0.4848484848484848);'>dimension</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.34567901234567905);'>constraint</span> <span style=''>set</span> <span style=''>and</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.4666666666666667);'>Rademacher</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>bound</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>providing</span> <span style=''>insights</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>Then</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>and</span> <span style=''>analyze</span> <span style='background-color:rgba(255, 0, 0, 0.6148148148148148);'>regularized</span> <span style=''>gradient</span> <span style=''>descent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>shallow</span> <span style=''>networks</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>problem</span> <span style=''>becomes</span> <span style=''>well</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditioned</span> <span style=''>and</span> <span style=''>local</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>occurs</span> <span style=''>once</span> <span style=''>the</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>data</span> <span style=''>exceeds</span> <span style=''>covering</span> <span style='background-color:rgba(255, 0, 0, 0.4848484848484848);'>dimension</span> <span style=''>(eg</span> <span style=''>of</span> <span style=''>nonzero</span> <span style=''>weights)</span> <span style=''>Finally</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>SpectralNet</span> <span style=''>Spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>using</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>Spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>is</span> <span style=''>a</span> <span style=''>leading</span> <span style=''>and</span> <span style=''>popular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>Two</span> <span style=''>of</span> <span style=''>its</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>limitations</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scalability</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>(ie</span> <span style=''>out</span> <span style=''>of</span> <span style=''>sample</span> <span style=''>extension)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overcomes</span> <span style=''>the</span> <span style=''>above</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>shortcomings</span> <span style=''>Our</span> <span style=''>network</span> <span style=''>which</span> <span style=''>we</span> <span style=''>call</span> <span style=''>SpectralNet</span> <span style=''>learns</span> <span style=''>a</span> <span style=''>map</span> <span style=''>that</span> <span style=''>embeds</span> <span style=''>input</span> <span style=''>data</span> <span style=''>points</span> <span style=''>into</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eigenspace</span> <span style=''>of</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Laplacian</span> <span style=''>matrix</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subsequently</span> <span style=''>clusters</span> <span style=''>them</span> <span style=''>We</span> <span style=''>train</span> <span style=''>SpectralNet</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>that</span> <span style=''>involves</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>allows</span> <span style=''>it</span> <span style=''>to</span> <span style=''>scale</span> <span style=''>to</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>while</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3); ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10972122944960686)
# 	representation (0.13009292351679771)
# 	architecture (0.0854181558255897)
# 	knowledge (0.12187276626161545)
# 	segmentation (0.07076483202287348)
# 	information (0.2426733380986419)
# 	detection (0.11543959971408149)
# 	different (0.2809149392423159)
# 	recognition (0.12437455325232309)
# 	convolutional (0.13545389563974267)
#
# Some Statistics words are:
# 	algorithm (0.37162837162837165)
# 	variational (0.10139860139860139)
# 	stochastic (0.13086913086913088)
# 	theoretical (0.15084915084915085)
# 	distribution (0.18181818181818182)
# 	statistical (0.17232767232767232)
# 	estimation (0.1928071928071928)
# 	dimensional (0.1913086913086913)
# 	inference (0.21078921078921078)
# 	regression (0.1838161838161838)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="67b817da-c252-4d1a-8c5b-8cb62366b8ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67b817da-c252-4d1a-8c5b-8cb62366b8ab")) {                    Plotly.newPlot(                        "67b817da-c252-4d1a-8c5b-8cb62366b8ab",                        [{"x":["implement","libraries","parallelization","subtraction","detecting","essential","segmentation","improvements","particularly","implementation","attempting","characteristics","techniques","compensate","surveillance","necessary","reference","recognition","successful","theoretical","applications","attributes","selection","detection","parallelized","available","important","technique","foreground","background","differencing","implemented","algorithm","artificial","favourably","pheromone","compromise","combinatorial","feedbacks","reallocate","accordingly","intelligence","symmetrical","optimization","benchmarks","described","biological","inclusion","benchmark","different","variables","particular","demonstrate","situations","discovery","identifiability","structure","condition","sufficient","multivariate","identified","performance","comparisons","bivariate","causality","conventional","continuous","uncertainty","practical","generated","framework","educational","platforms","assessments","automatically","education","technology","comprises","leverages","prominently","remaining","assignment","submission","determine","algorithms","questions","assignments","automatic","substantially","communication","partially","solutions","correctness","nonparametrics","technologies","structures","numerical","mathematical","effective","inspiration","incorrect","locations","processing","engineering","clustering","approaches","instructor","satisfies","selecting","theoretic","centroids","classical","approximately","information","depending","inequality","sensitive","algorithmic","parametrized","classification","stability","analogous","generalization","immediately","parallels","functions","empirical","inequalities","consequently","equivalently","hypothesis","difference","concentration","properties","interesting","association","perturbation","quantifies","treatment","challenge","operators","constructs","combination","opportunities","preferences","computation","determines","combinations","parameter","architecture","disadvantages","diversity","multitude","reinforcement","difficult","constitute","mechanism","parameters","especially","formulation","coefficients","measurement","comparable","previously","introduce","therefore","regularizer","compressed","literature","correlated","regression","belonging","exhibiting","introduced","subsequent","efficiency","investigate","instances","effectiveness","considerably","execution","worthwhile","additional","practicability","desirable","simplification","infeasible","maximizing","criterion","behaviour","metalevel","improvement","incremental","essentially","stochastic","heuristic","outperform","formalize","establishes","variations","confidence","prediction","deduction","predictability","autonomous","knowledge","generating","systematic","optimized","convolutional","inherently","auxiliary","underneath","suggestions","application","introduction","reasoning","effectively","exploitation","indicators","univariate","densities","unexpected","rectangular","integration","arbitrarily","omnipresent","generally","propagation","mathematics","probability","polyhedral","elucidate","derivations","expectation","empirically","theoretically","probabilities","approximation","cumulative","calculate","approximate","simulated","dimensional","classifying","nonparametric","developed","completely","performed","specifically","classifications","discussed","classifier","procedures","treatments","discrimination","effici ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	omnipresent
# 	clairvoyant
# 	quadratures
# 	quadrature
# 	clarified
# 	unconditional
# 	posteriors
# 	reparameterized
# 	degenerate
# 	multiplier
# 	sparsification
# 	reconstructive
# 	privileged
# 	unspecified
# 	datapoint
# 	initialising
# 	criterions
# 	polylogarithmic
# 	regressionclassification
# 	unsettled
# Some words which never appear in Statistics papers:
# 	differencing
# 	pheromone
# 	feedbacks
# 	reallocate
# 	symmetrical
# 	practicability
# 	metalevel
# 	underneath
# 	extractive
# 	naturalness
# 	specifications
# 	ultrasound
# 	directing
# 	constancy
# 	emergencies
# 	earthquake
# 	disasters
# 	crossover
# 	exchanging
# 	declarative

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.069085105729982e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7716666666666666
